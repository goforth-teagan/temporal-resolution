# %% [markdown]
# # Plots -- plots created are exported to file, not shown here

# %%
#importing packages needed for analysis
import os
import numpy as np
import pandas as pd
import math
from pandas import DataFrame
import matplotlib as mpl 

path = os.getcwd()
#print(path)

#this code creates an output directory in the parent director, if one does not exist yet
#Note: this is where all of the output files will be written, since outputs are large this saves space in git
path = os.getcwd()
parent = os.path.dirname(path)
outputs_dir = parent+'\outputs\plots'
if not os.path.exists(outputs_dir):
    os.makedirs(outputs_dir)
print('output files are written out in parent directory: '+outputs_dir)

##UNCOMMENT WHICH PROFILE BEING ANALYZED 
x = 'load'
x2 = 'Load'

#x = 'solar'
#x2 = 'Solar_Gen'

#x = 'wind'
#x2 = 'Wind_Gen'
# Out:
# output files are written out in parent directory: C:\Users\tgoforth\Documents\IPM temporal resolution project\outputs\plots

# %% [markdown]
# # Import Data

# %%
############### IPM APPROACH (2 profiles) ###############
# norm
IPM1 = pd.read_csv('../outputs/error_analysis/'+x+'_norm_diff.csv')
IPM1_name = 'norm'
IPM1 = IPM1[IPM1['R_Group']=='FRCC']

# TOD before group
IPM2 = pd.read_csv('../outputs/error_analysis/'+x+'_timeofday_diff.csv')
IPM2_name = 'time of day'
IPM2 = IPM2[IPM2['R_Group']=='FRCC']

############### SEQUENTIAL APPROACH (9 profiles) ###############
# 1-hr
seq1 = pd.read_csv('../outputs/error_analysis/'+x+'_bind_8760hr_diff.csv')
seq1_name = 'seq 1hr'
seq1 = seq1[seq1['R_Group']=='FRCC']

# 2-hr
seq2 = pd.read_csv('../outputs/error_analysis/'+x+'_seq_2hr_diff.csv')
seq2_name = 'seq 2hr'
seq2 = seq2[seq2['R_Group']=='FRCC']

# 4-hr
seq3 = pd.read_csv('../outputs/error_analysis/'+x+'_seq_4hr_diff.csv')
seq3_name = 'seq 4hr'
seq3 = seq3[seq3['R_Group']=='FRCC']

# 8-hr
seq4 = pd.read_csv('../outputs/error_analysis/'+x+'_seq_8hr_diff.csv')
seq4_name = 'seq 8hr'
seq4 = seq4[seq4['R_Group']=='FRCC']

# 12-hr
seq5 = pd.read_csv('../outputs/error_analysis/'+x+'_seq_12hr_diff.csv')
seq5_name = 'seq 12hr'
seq5 = seq5[seq5['R_Group']=='FRCC']

# 24-hr
seq6 = pd.read_csv('../outputs/error_analysis/'+x+'_seq_24hr_diff.csv')
seq6_name = 'seq 24hr'
seq6 = seq6[seq6['R_Group']=='FRCC']

# 48-hr
seq7 = pd.read_csv('../outputs/error_analysis/'+x+'_seq_48hr_diff.csv')
seq7_name = 'seq 48hr'
seq7 = seq7[seq7['R_Group']=='FRCC']

# 120-hr
seq8 = pd.read_csv('../outputs/error_analysis/'+x+'_seq_120hr_diff.csv')
seq8_name = 'seq 120hr'
seq8 = seq8[seq8['R_Group']=='FRCC']

seq9 = pd.read_csv('../outputs/error_analysis/'+x+'_bind_1hr_diff.csv')
seq9_name = 'seq 8760hr'
seq9 = seq9[seq9['R_Group']=='FRCC']

############### ONE/TWO DAY APPROACH (7 profiles) ###############
# One day type, monthly, 24 hrs
dt1 = pd.read_csv('../outputs/error_analysis/'+x+'_1daytype_monthly_24hr_diff.csv')
dt1_name = '1 daytype, monthly, 24hr'
dt1 = dt1[dt1['R_Group']=='FRCC']

# One day type, season, 24 hrs
dt2 = pd.read_csv('../outputs/error_analysis/'+x+'_1daytype_season_24hr_diff.csv')
dt2_name = '1 daytype, season, 24hr'
dt2 = dt2[dt2['R_Group']=='FRCC']

# Two day type, monthly, 24 hrs
dt3 = pd.read_csv('../outputs/error_analysis/'+x+'_2daytype_monthly_24hr_diff.csv')
dt3_name = '2 daytype, monthly, 24hr'
dt3 = dt3[dt3['R_Group']=='FRCC']

# Two day type, season, 24 hrs#
dt4 = pd.read_csv('../outputs/error_analysis/'+x+'_2daytype_season_24hr_diff.csv')
dt4_name = '2 daytype, season, 24hr'
dt4 = dt4[dt4['R_Group']=='FRCC']

# Two day type, monthly, 4 hrs
dt5 = pd.read_csv('../outputs/error_analysis/'+x+'_2daytype_month_4hr_diff.csv')
dt5_name = '2 daytype, month, 4hr'
dt5 = dt5[dt5['R_Group']=='FRCC']

# Two day type, bimonthly, 4 hrs
dt6 = pd.read_csv('../outputs/error_analysis/'+x+'_2daytype_bimonth_4hr_diff.csv')
dt6_name = '2 daytype, bimonth, 4hr'
dt6 = dt6[dt6['R_Group']=='FRCC']

# Two day type, season, 4 hrs
dt7 = pd.read_csv('../outputs/error_analysis/'+x+'_2daytype_season_4hr_diff.csv')
dt7_name = '2 daytype, season, 4hr'
dt7 = dt7[dt7['R_Group']=='FRCC']

############### THREE DAY TYPE APPROACH (6 profiles) ###############
# Three day type, monthly, 24 hrs
peak1 = pd.read_csv('../outputs/error_analysis/'+x+'_3daytype_monthly_24hr_diff.csv')
peak1_name = '3 daytype, month, 24hr'
peak1 = peak1[peak1['R_Group']=='FRCC']

# Three day type, season, 24 hrs
peak2 = pd.read_csv('../outputs/error_analysis/'+x+'_3daytype_season_24hr_diff.csv')
peak2_name = '3 daytype, season, 24hr'
peak2 = peak2[peak2['R_Group']=='FRCC']

# Three day type, annual, 24 hrs
peak3 = pd.read_csv('../outputs/error_analysis/'+x+'_3daytype_annual_24hr_diff.csv')
peak3_name = '3 daytype, annual, 24hr'
peak3 = peak3[peak3['R_Group']=='FRCC']

# Three day type, bimonthly, 4 hrs
peak4 = pd.read_csv('../outputs/error_analysis/'+x+'_3daytype_bimonth_4hr_diff.csv')
peak4_name = '3 daytype, bimonth. 4hr'
peak4 = peak4[peak4['R_Group']=='FRCC']

# Three day type, season based, 4 hrs
peak5 = pd.read_csv('../outputs/error_analysis/'+x+'_3daytype_seasonbased_4hr_diff.csv')
peak5_name = '3 daytype, seasonbased, 4hr'
peak5 = peak5[peak5['R_Group']=='FRCC']

# Three day type, season, 4 hrs
peak6 = pd.read_csv('../outputs/error_analysis/'+x+'_3daytype_season_4hr_diff.csv')
peak6_name = '3 daytype, season, 4hr'
peak6 = peak6[peak6['R_Group']=='FRCC']

# %% [markdown]
# # Difference Boxplots

# %%
# %matplotlib inline

## agg backend is used to create plot as a .png file
mpl.use('agg')

import matplotlib.pyplot as plt

# %%
data_plot1 = [IPM1['Diff'],IPM2['Diff']]
data_plot1_names = [IPM1_name,IPM2_name]

# Create a figure instance
fig = plt.figure()

# Creating axes instance 
ax = fig.add_axes([0, 0, 1, 1])

# Create the boxplot
bp = ax.boxplot(data_plot1)

## Custom x-axis labels
ax.set_xticklabels(data_plot1_names)

# Save the figure
fig.savefig('../outputs/plots/IPM_boxplot.png', bbox_inches='tight')

# %%
data_plot2 = [IPM1['Diff'],seq1['Diff'],seq2['Diff'],seq3['Diff'],seq4['Diff'],seq5['Diff'],
              seq6['Diff'],seq7['Diff'],seq8['Diff'],seq9['Diff']]
data_plot2_names = [IPM1_name,seq1_name,seq2_name,seq3_name,seq4_name,seq5_name,seq6_name,
                   seq7_name,seq8_name,seq9_name]

# Create a figure instance
fig = plt.figure()

# Creating axes instance 
ax = fig.add_axes([0, 0, 1, 1])

# Create the boxplot
bp = ax.boxplot(data_plot2)

## Custom x-axis labels
ax.set_xticklabels(data_plot2_names)
plt.xticks(rotation=70)

# Save the figure
fig.savefig('../outputs/plots/seq_boxplot.png', bbox_inches='tight')

# %%
data_plot3 = [IPM1['Diff'],dt1['Diff'],dt2['Diff'],dt3['Diff'],dt4['Diff'],dt5['Diff'],
              dt6['Diff'],dt7['Diff']]
data_plot3_names = [IPM1_name,dt1_name,dt2_name,dt3_name,dt4_name,dt5_name,dt6_name,dt7_name]

# Create a figure instance
fig = plt.figure()

# Creating axes instance 
ax = fig.add_axes([0, 0, 1, 1])

# Create the boxplot
bp = ax.boxplot(data_plot3)

## Custom x-axis labels
ax.set_xticklabels(data_plot3_names)
plt.xticks(rotation=70)

# Save the figure
fig.savefig('../outputs/plots/dt_boxplot.png', bbox_inches='tight')

# %%
data_plot4 = [IPM1['Diff'],peak1['Diff'],peak2['Diff'],peak3['Diff'],peak4['Diff'],
              peak5['Diff'],peak6['Diff']]
data_plot4_names = [IPM1_name,peak1_name,peak2_name,peak3_name,peak4_name,peak5_name,peak6_name]

# Create a figure instance
fig = plt.figure()

# Creating axes instance 
ax = fig.add_axes([0, 0, 1, 1])

# Create the boxplot
bp = ax.boxplot(data_plot4)

## Custom x-axis labels
ax.set_xticklabels(data_plot4_names)
plt.xticks(rotation=70)

# Save the figure
fig.savefig('../outputs/plots/3dt_boxplot.png', bbox_inches='tight')

# %% [markdown]
# # Load Plots

# %%
#import data

profiles = ['norm','timeofday','bind_8760hr','seq_2hr','seq_4hr','seq_8hr','seq_12hr','seq_24hr','seq_48hr',
           'seq_120hr','bind_1hr','1daytype_monthly_24hr','1daytype_season_24hr','2daytype_monthly_24hr',
            '2daytype_season_24hr','2daytype_month_4hr','2daytype_bimonth_4hr','2daytype_season_4hr',
            '3daytype_monthly_24hr','3daytype_season_24hr','3daytype_annual_24hr','3daytype_bimonth_4hr',
            '3daytype_seasonbased_4hr','3daytype_season_4hr']

data = ['IPM1_load','IPM2_load','seq1_load','seq2_load','seq3_load','seq4_load','seq5_load','seq6_load',
            'seq7_load','seq8_load','seq9_load','dt1_load','dt2_load','dt3_load','dt4_load','dt5_load','dt6_load',
            'dt7_load','peak1_load','peak2_load','peak3_load','peak4_load','peak5_load','peak6_load']

data2 = []

for i in range(len(profiles)):
    data[i] = pd.read_csv('../outputs/'+x+'/'+x+'_8760_'+profiles[i]+'.csv')
    data[i] = data[i][data[i]['R_Group']=='FRCC']
    data2.append(data[i])
# Out:
# [       Unnamed: 0 Region R_Group R_Subgroup    Season  Month  Day  Hour  \
# 17520
#
# [8760 rows x 16 columns],        Unnamed: 0 Region R_Group R_Subgroup    Season  Month  Day  Hour  \
# 17520       39786   FRCC    FRCC       FRCC    winter      1    2     2
# 17521       17593   FRCC    FRCC       FRCC  shoulder      3   74     1
# 17522       17521   FRCC    FRCC       FRCC    winter      1    2     1
# 17523       39863   FRCC    FRCC       FRCC  shoulder      3   79     2
# 17524       17592   FRCC    FRCC       FRCC  shoulder      3   73     1
# ...           ...    ...     ...        ...       ...    ...  ...   ...
# 26275      284871   FRCC    FRCC       FRCC    summer      6  172    13
# 26276      284916   FRCC    FRCC       FRCC    summer      8  217    13
# 26277      307136   FRCC    FRCC       FRCC    summer      6  172    14
# 26278      284872   FRCC    FRCC       FRCC    summer      6  173    13
# 26279      307137   FRCC    FRCC       FRCC    summer      6  173    14
#
#         Load        Date  DOW  Weekday  Hour_Tot      Tot           Avg
# 17520  15694  2011-07-17    6    False         7   123898  17699.714286
# 17521  15738  2011-01-04    1     True        31   519021  16742.612903
# 17522  15750  2011-01-01    5    False        31   626801  20219.387097
# 17523  15822  2011-07-20    2     True        31   524254  16911.419355
# 17524  15831  2011-01-04    1     True        31   519021  16742.612903
# ...      ...         ...  ...      ...       ...      ...           ...
# 26275  45925  2011-07-09    5    False        25  1034029  41361.160000
# 26276  45949  2011-07-11    0     True        31  1300474  41950.774194
# 26277  46240  2011-01-23    6    False        30  1226738  40891.266667
# 26278  46362  2011-07-09    5    False        25  1034029  41361.160000
# 26279  46408  2011-01-23    6    False        30  1226738  40891.266667
#
# [8760 rows x 15 columns],        Unnamed: 0 Region R_Group R_Subgroup    Season  Month  Day  Hour  \
# 17520       39786   FRCC    FRCC       FRCC    winter      1    2     2
# 17521       17593   FRCC    FRCC       FRCC  shoulder      3   74     1
# 17522       17521   FRCC    FRCC       FRCC    winter      1    2     1
# 17523       39863   FRCC    FRCC       FRCC  shoulder      3   79     2
# 17524       17592   FRCC    FRCC       FRCC  shoulder      3   73     1
# ...           ...    ...     ...        ...       ...    ...  ...   ...
# 26275      284871   FRCC    FRCC       FRCC    summer      6  172    13
# 26276      284916   FRCC    FRCC       FRCC    summer      8  217    13
# 26277      307136   FRCC    FRCC       FRCC    summer      6  172    14
# 26278      284872   FRCC    FRCC       FRCC    summer      6  173    13
# 26279      307137   FRCC    FRCC       FRCC    summer      6  173    14
#
#         Load        Date  DOW  Weekday  Season_Group  Hour_Tot      Tot  \
# 17520  15694  2011-07-17    6    False             1        16   281976
# 17521  15738  2011-01-04    1     True             2       122  2159594
# 17522  15750  2011-01-01    5    False             1        77  1444154
# 17523  15822  2011-07-20    2     True             2        83  1498298
# 17524  15831  2011-01-04    1     True             2       122  2159594
# ...      ...         ...  ...      ...           ...       ...      ...
# 26275  45925  2011-07-09    5    False             4        25  1034029
# 26276  45949  2011-07-11    0     True             5        39  1644160
# 26277  46240  2011-01-23    6    False             4        30  1226738
# 26278  46362  2011-07-09    5    False             4        25  1034029
# 26279  46408  2011-01-23    6    False             4        30  1226738
#
#                 Avg
# 17520  17623.500000
# 17521  17701.590164
# 17522  18755.246753
# 17523  18051.783133
# 17524  17701.590164
# ...             ...
# 26275  41361.160000
# 26276  42157.948718
# 26277  40891.266667
# 26278  41361.160000
# 26279  40891.266667
#
# [8760 rows x 16 columns],        Unnamed: 0 Region R_Group R_Subgroup    Season  Month  Day  Hour  \
# 17520       39786   FRCC    FRCC       FRCC    winter      1    2     2
# 17521       17593   FRCC    FRCC       FRCC  shoulder      3   74     1
# 17522       17521   FRCC    FRCC       FRCC    winter      1    2     1
# 17523       39863   FRCC    FRCC       FRCC  shoulder      3   79     2
# 17524       17592   FRCC    FRCC       FRCC  shoulder      3   73     1
# ...           ...    ...     ...        ...       ...    ...  ...   ...
# 26275      284871   FRCC    FRCC       FRCC    summer      6  172    13
# 26276      284916   FRCC    FRCC       FRCC    summer      8  217    13
# 26277      307136   FRCC    FRCC       FRCC    summer      6  172    14
# 26278      284872   FRCC    FRCC       FRCC    summer      6  173    13
# 26279      307137   FRCC    FRCC       FRCC    summer      6  173    14
#
#         Load        Date  DOW  Weekday  4-hr  Hour_Tot     Tot       Avg
# 17520  15694  2011-07-17    6    False     1         4   64198  16049.50
# 17521  15738  2011-01-04    1     True     1         4   69369  17342.25
# 17522  15750  2011-01-01    5    False     1         4   64198  16049.50
# 17523  15822  2011-07-20    2     True     1         4   64511  16127.75
# 17524  15831  2011-01-04    1     True     1         4   71202  17800.50
# ...      ...         ...  ...      ...   ...       ...     ...       ...
# 26275  45925  2011-07-09    5    False     4         4  182194  45548.50
# 26276  45949  2011-07-11    0     True     4         4  180069  45017.25
# 26277  46240  2011-01-23    6    False     4         4  182194  45548.50
# 26278  46362  2011-07-09    5    False     4         4  182085  45521.25
# 26279  46408  2011-01-23    6    False     4         4  182085  45521.25
#
# [8760 rows x 16 columns],        Unnamed: 0 Region R_Group R_Subgroup    Season  Month  Day  Hour  \
# 17520       39786   FRCC    FRCC       FRCC    winter      1    2     2
# 17521       17593   FRCC    FRCC       FRCC  shoulder      3   74     1
# 17522       17521   FRCC    FRCC       FRCC    winter      1    2     1
# 17523       39863   FRCC    FRCC       FRCC  shoulder      3   79     2
# 17524       17592   FRCC    FRCC       FRCC  shoulder      3   73     1
# ...           ...    ...     ...        ...       ...    ...  ...   ...
# 26275      284871   FRCC    FRCC       FRCC    summer      6  172    13
# 26276      284916   FRCC    FRCC       FRCC    summer      8  217    13
# 26277      307136   FRCC    FRCC       FRCC    summer      6  172    14
# 26278      284872   FRCC    FRCC       FRCC    summer      6  173    13
# 26279      307137   FRCC    FRCC       FRCC    summer      6  173    14
#
#         Load        Date  DOW  Weekday  4-hr  Bimonth  Hour_Tot     Tot  \
# 17520  15694  2011-07-17    6    False     1        1         4   64198
# 17521  15738  2011-01-04    1     True     1        2         4   69369
# 17522  15750  2011-01-01    5    False     1        1         4   64198
# 17523  15822  2011-07-20    2     True     1        2         4   64511
# 17524  15831  2011-01-04    1     True     1        2         4   71202
# ...      ...         ...  ...      ...   ...      ...       ...     ...
# 26275  45925  2011-07-09    5    False     4        3         4  182194
# 26276  45949  2011-07-11    0     True     4        4         4  180069
# 26277  46240  2011-01-23    6    False     4        3         4  182194
# 26278  46362  2011-07-09    5    False     4        3         4  182085
# 26279  46408  2011-01-23    6    False     4        3         4  182085
#
#             Avg
# 17520  16049.50
# 17521  17342.25
# 17522  16049.50
# 17523  16127.75
# 17524  17800.50
# ...         ...
# 26275  45548.50
# 26276  45017.25
# 26277  45548.50
# 26278  45521.25
# 26279  45521.25
#
# [8760 rows x 17 columns],        Unnamed: 0 Region R_Group R_Subgroup    Season  Month  Day  Hour  \
# 17520       39786   FRCC    FRCC       FRCC    winter      1    2     2
# 17521       17593   FRCC    FRCC       FRCC  shoulder      3   74     1
# 17522       17521   FRCC    FRCC       FRCC    winter      1    2     1
# 17523       39863   FRCC    FRCC       FRCC  shoulder      3   79     2
# 17524       17592   FRCC    FRCC       FRCC  shoulder      3   73     1
# ...           ...    ...     ...        ...       ...    ...  ...   ...
# 26275      284871   FRCC    FRCC       FRCC    summer      6  172    13
# 26276      284916   FRCC    FRCC       FRCC    summer      8  217    13
# 26277      307136   FRCC    FRCC       FRCC    summer      6  172    14
# 26278      284872   FRCC    FRCC       FRCC    summer      6  173    13
# 26279      307137   FRCC    FRCC       FRCC    summer      6  173    14
#
#         Load        Date  DOW  Weekday  4-hr  Season_Group  Hour_Tot  \
# 17520  15694  2011-07-17    6    False     1             1        93
# 17521  15738  2011-01-04    1     True     1             2       331
# 17522  15750  2011-01-01    5    False     1             1        93
# 17523  15822  2011-07-20    2     True     1             2       331
# 17524  15831  2011-01-04    1     True     1             2       331
# ...      ...         ...  ...      ...   ...           ...       ...
# 26275  45925  2011-07-09    5    False     4             4       162
# 26276  45949  2011-07-11    0     True     4             5       450
# 26277  46240  2011-01-23    6    False     4             4       162
# 26278  46362  2011-07-09    5    False     4             4       162
# 26279  46408  2011-01-23    6    False     4             4       162
#
#             Tot           Avg
# 17520   1726130  18560.537634
# 17521   6111534  18463.848943
# 17522   1726130  18560.537634
# 17523   6111534  18463.848943
# 17524   6111534  18463.848943
# ...         ...           ...
# 26275   6374603  39349.401235
# 26276  17867348  39705.217778
# 26277   6374603  39349.401235
# 26278   6374603  39349.401235
# 26279   6374603  39349.401235
#
# [8760 rows x 17 columns],        Unnamed: 0 Region R_Group R_Subgroup    Season  Month  Day  Hour  \
# 17520       17545   FRCC    FRCC       FRCC    winter      1    2     2
# 17521       19272   FRCC    FRCC       FRCC  shoulder      3   74     1
# 17522       17544   FRCC    FRCC       FRCC    winter      1    2     1
# 17523       19393   FRCC    FRCC       FRCC  shoulder      3   79     2
# 17524       19248   FRCC    FRCC       FRCC  shoulder      3   73     1
# ...           ...    ...     ...        ...       ...    ...  ...   ...
# 26275       21636   FRCC    FRCC       FRCC    summer      6  172    13
# 26276       22716   FRCC    FRCC       FRCC    summer      8  217    13
# 26277       21637   FRCC    FRCC       FRCC    summer      6  172    14
# 26278       21660   FRCC    FRCC       FRCC    summer      6  173    13
# 26279       21661   FRCC    FRCC       FRCC    summer      6  173    14
#
#         Load        Date  DOW Day_Type  Hour_Counter  Hour_Tot      Tot  \
# 17520  15694  2011-07-17    6  Weekend            26         7   123898
# 17521  15738  2011-01-04    1  Weekday          1753        30   501151
# 17522  15750  2011-01-01    5  Weekend            25        30   594451
# 17523  15822  2011-07-20    2  Weekday          1874        30   506236
# 17524  15831  2011-01-04    1  Weekday          1729        30   501151
# ...      ...         ...  ...      ...           ...       ...      ...
# 26275  45925  2011-07-09    5  Weekend          4117        24   987667
# 26276  45949  2011-07-11    0     Peak          5197         1    45949
# 26277  46240  2011-01-23    6  Weekend          4118        29  1180330
# 26278  46362  2011-07-09    5     Peak          4141         1    46362
# 26279  46408  2011-01-23    6     Peak          4142         1    46408
#
#                 Avg
# 17520  17699.714286
# 17521  16705.033333
# 17522  19815.033333
# 17523  16874.533333
# 17524  16705.033333
# ...             ...
# 26275  41152.791667
# 26276  45949.000000
# 26277  40701.034483
# 26278  46362.000000
# 26279  46408.000000
#
# [8760 rows x 16 columns],        Unnamed: 0 Region R_Group R_Subgroup    Season  Month  Day  Hour  \
# 17520       17545   FRCC    FRCC       FRCC    winter      1    2     2
# 17521       19272   FRCC    FRCC       FRCC  shoulder      3   74     1
# 17522       17544   FRCC    FRCC       FRCC    winter      1    2     1
# 17523       19393   FRCC    FRCC       FRCC  shoulder      3   79     2
# 17524       19248   FRCC    FRCC       FRCC  shoulder      3   73     1
# ...           ...    ...     ...        ...       ...    ...  ...   ...
# 26275       21636   FRCC    FRCC       FRCC    summer      6  172    13
# 26276       22716   FRCC    FRCC       FRCC    summer      8  217    13
# 26277       21637   FRCC    FRCC       FRCC    summer      6  172    14
# 26278       21660   FRCC    FRCC       FRCC    summer      6  173    13
# 26279       21661   FRCC    FRCC       FRCC    summer      6  173    14
#
#         Load        Date  DOW Day_Type  Hour_Counter  Hour_Tot      Tot  \
# 17520  15694  2011-07-17    6  Weekend            26        16   281976
# 17521  15738  2011-01-04    1  Weekday          1753       118  2081222
# 17522  15750  2011-01-01    5  Weekend            25        74  1371860
# 17523  15822  2011-07-20    2  Weekday          1874        80  1438890
# 17524  15831  2011-01-04    1  Weekday          1729       118  2081222
# ...      ...         ...  ...      ...           ...       ...      ...
# 26275  45925  2011-07-09    5  Weekend          4117        47  1921141
# 26276  45949  2011-07-11    0     Peak          5197         5   221072
# 26277  46240  2011-01-23    6  Weekend          4118        46  1858560
# 26278  46362  2011-07-09    5     Peak          4141         5   221072
# 26279  46408  2011-01-23    6     Peak          4142         5   221489
#
#                 Avg
# 17520  17623.500000
# 17521  17637.474576
# 17522  18538.648649
# 17523  17986.125000
# 17524  17637.474576
# ...             ...
# 26275  40875.340426
# 26276  44214.400000
# 26277  40403.478261
# 26278  44214.400000
# 26279  44297.800000
#
# [8760 rows x 16 columns],        Unnamed: 0 Region R_Group R_Subgroup    Season  Month  Day  Hour  \
# 17520       17545   FRCC    FRCC       FRCC    winter      1    2     2
# 17521       19272   FRCC    FRCC       FRCC  shoulder      3   74     1
# 17522       17544   FRCC    FRCC       FRCC    winter      1    2     1
# 17523       19393   FRCC    FRCC       FRCC  shoulder      3   79     2
# 17524       19248   FRCC    FRCC       FRCC  shoulder      3   73     1
# ...           ...    ...     ...        ...       ...    ...  ...   ...
# 26275       21636   FRCC    FRCC       FRCC    summer      6  172    13
# 26276       22716   FRCC    FRCC       FRCC    summer      8  217    13
# 26277       21637   FRCC    FRCC       FRCC    summer      6  172    14
# 26278       21660   FRCC    FRCC       FRCC    summer      6  173    13
# 26279       21661   FRCC    FRCC       FRCC    summer      6  173    14
#
#         Load        Date  DOW Day_Type  Hour_Counter  Hour_Tot      Tot  \
# 17520  15694  2011-07-17    6  Weekend            26       100  1885414
# 17521  15738  2011-01-04    1  Weekday          1753       233  4499127
# 17522  15750  2011-01-01    5  Weekend            25       120  2424299
# 17523  15822  2011-07-20    2  Weekday          1874       253  5042810
# 17524  15831  2011-01-04    1  Weekday          1729       233  4499127
# ...      ...         ...  ...      ...           ...       ...      ...
# 26275  45925  2011-07-09    5  Weekend          4117       122  3817902
# 26276  45949  2011-07-11    0     Peak          5197        12   447990
# 26277  46240  2011-01-23    6  Weekend          4118       111  3533458
# 26278  46362  2011-07-09    5     Peak          4141        12   447990
# 26279  46408  2011-01-23    6     Peak          4142        12   448439
#
#                 Avg
# 17520  18854.140000
# 17521  19309.557940
# 17522  20202.491667
# 17523  19932.055336
# 17524  19309.557940
# ...             ...
# 26275  31294.278689
# 26276  37332.500000
# 26277  31832.954955
# 26278  37332.500000
# 26279  37369.916667
#
# [8760 rows x 16 columns],        Unnamed: 0 Region R_Group R_Subgroup    Season  Month  Day  Hour  \
# 17520       39786   FRCC    FRCC       FRCC    winter      1    2     2
# 17521       17593   FRCC    FRCC       FRCC  shoulder      3   74     1
# 17522       17521   FRCC    FRCC       FRCC    winter      1    2     1
# 17523       39863   FRCC    FRCC       FRCC  shoulder      3   79     2
# 17524       17592   FRCC    FRCC       FRCC  shoulder      3   73     1
# ...           ...    ...     ...        ...       ...    ...  ...   ...
# 26275      284871   FRCC    FRCC       FRCC    summer      6  172    13
# 26276      284916   FRCC    FRCC       FRCC    summer      8  217    13
# 26277      307136   FRCC    FRCC       FRCC    summer      6  172    14
# 26278      284872   FRCC    FRCC       FRCC    summer      6  173    13
# 26279      307137   FRCC    FRCC       FRCC    summer      6  173    14
#
#         Load        Date  DOW Day_Type  4-hr  Bimonth  Hour_Tot      Tot  \
# 17520  15694  2011-07-17    6  Weekend     1        1        53  1017418
# 17521  15738  2011-01-04    1  Weekday     1        2       181  3283484
# 17522  15750  2011-01-01    5  Weekend     1        1        53  1017418
# 17523  15822  2011-07-20    2  Weekday     1        2       181  3283484
# 17524  15831  2011-01-04    1  Weekday     1        2       181  3283484
# ...      ...         ...  ...      ...   ...      ...       ...      ...
# 26275  45925  2011-07-09    5  Weekend     4        3        98  3860934
# 26276  45949  2011-07-11    0     Peak     4        4         8   360747
# 26277  46240  2011-01-23    6  Weekend     4        3        98  3860934
# 26278  46362  2011-07-09    5     Peak     4        3         8   345369
# 26279  46408  2011-01-23    6     Peak     4        3         8   345369
#
#                 Avg
# 17520  19196.566038
# 17521  18140.795580
# 17522  19196.566038
# 17523  18140.795580
# 17524  18140.795580
# ...             ...
# 26275  39397.285714
# 26276  45093.375000
# 26277  39397.285714
# 26278  43171.125000
# 26279  43171.125000
#
# [8760 rows x 17 columns],        Unnamed: 0 Region R_Group R_Subgroup    Season  Month  Day  Hour  \
# 17520       39786   FRCC    FRCC       FRCC    winter      1    2     2
# 17521       17593   FRCC    FRCC       FRCC  shoulder      3   74     1
# 17522       17521   FRCC    FRCC       FRCC    winter      1    2     1
# 17523       39863   FRCC    FRCC       FRCC  shoulder      3   79     2
# 17524       17592   FRCC    FRCC       FRCC  shoulder      3   73     1
# ...           ...    ...     ...        ...       ...    ...  ...   ...
# 26275      284871   FRCC    FRCC       FRCC    summer      6  172    13
# 26276      284916   FRCC    FRCC       FRCC    summer      8  217    13
# 26277      307136   FRCC    FRCC       FRCC    summer      6  172    14
# 26278      284872   FRCC    FRCC       FRCC    summer      6  173    13
# 26279      307137   FRCC    FRCC       FRCC    summer      6  173    14
#
#         Load        Date  DOW Day_Type  4-hr  Season_Group  Hour_Tot      Tot  \
# 17520  15694  2011-07-17    6  Weekend     1             1        90  1653836
# 17521  15738  2011-01-04    1  Weekday     1             2       322  5931200
# 17522  15750  2011-01-01    5  Weekend     1             1        90  1653836
# 17523  15822  2011-07-20    2  Weekday     1             2       322  5931200
# 17524  15831  2011-01-04    1  Weekday     1             2       322  5931200
# ...      ...         ...  ...      ...   ...           ...       ...      ...
# 26275  45925  2011-07-09    5  Weekend     4             4        53  2167997
# 26276  45949  2011-07-11    0     Peak     4             5         8   360747
# 26277  46240  2011-01-23    6  Weekend     4             4        53  2167997
# 26278  46362  2011-07-09    5     Peak     4             4         4   182085
# 26279  46408  2011-01-23    6     Peak     4             4         4   182085
#
#                 Avg
# 17520  18375.955556
# 17521  18419.875776
# 17522  18375.955556
# 17523  18419.875776
# 17524  18419.875776
# ...             ...
# 26275  40905.603774
# 26276  45093.375000
# 26277  40905.603774
# 26278  45521.250000
# 26279  45521.250000
#
# [8760 rows x 17 columns],        Unnamed: 0 Region R_Group R_Subgroup    Season  Month  Day  Hour  \
# 17520       39786   FRCC    FRCC       FRCC    winter      1    2     2
# 17521       17593   FRCC    FRCC       FRCC  shoulder      3   74     1
# 17522       17521   FRCC    FRCC       FRCC    winter      1    2     1
# 17523       39863   FRCC    FRCC       FRCC  shoulder      3   79     2
# 17524       17592   FRCC    FRCC       FRCC  shoulder      3   73     1
# ...           ...    ...     ...        ...       ...    ...  ...   ...
# 26275      284871   FRCC    FRCC       FRCC    summer      6  172    13
# 26276      284916   FRCC    FRCC       FRCC    summer      8  217    13
# 26277      307136   FRCC    FRCC       FRCC    summer      6  172    14
# 26278      284872   FRCC    FRCC       FRCC    summer      6  173    13
# 26279      307137   FRCC    FRCC       FRCC    summer      6  173    14
#
#         Load        Date  DOW Day_Type  4-hr  Hour_Tot      Tot           Avg
# 17520  15694  2011-07-17    6  Weekend     1        90  1653836  18375.955556
# 17521  15738  2011-01-04    1  Weekday     1       322  5931200  18419.875776
# 17522  15750  2011-01-01    5  Weekend     1        90  1653836  18375.955556
# 17523  15822  2011-07-20    2  Weekday     1       322  5931200  18419.875776
# 17524  15831  2011-01-04    1  Weekday     1       322  5931200  18419.875776
# ...      ...         ...  ...      ...   ...       ...      ...           ...
# 26275  45925  2011-07-09    5  Weekend     4       157  6159791  39234.337580
# 26276  45949  2011-07-11    0     Peak     4        20   870841  43542.050000
# 26277  46240  2011-01-23    6  Weekend     4       157  6159791  39234.337580
# 26278  46362  2011-07-09    5     Peak     4        20   870841  43542.050000
# 26279  46408  2011-01-23    6     Peak     4        20   870841  43542.050000
#
# [8760 rows x 16 columns]]

# %%
# iterate through data 
for i in range(len(data2)):
    plt.clf()
    z = data2[i]
    z = z.sort_values(by=['Region','Season',x2],ascending=[True, True, False])
    plt.plot(z[x2].values)
    
    z = z.sort_values(by=['Region','Season','Avg'],ascending=[True, True, False])
    plt.plot(z['Avg'].values)
    plt.xlabel('Hours')
    plt.ylabel(x2)
    plt.title(profiles[i])
    
    fig.savefig('../outputs/plots/'+profiles[i]+'_load_plot.png', bbox_inches='tight')
